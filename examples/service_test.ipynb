# %%
import io
import requests
import pandas as pd

# %%
server_url: str = "http://127.0.0.1:8000"
data_url: str = (
    "https://raw.githubusercontent.com/hse-mlds/ml/main/hometasks/HT1/cars_train.csv"
)

# %%
# test /predict_item

path = "/predict_item"
df = pd.read_csv(data_url)
item = df.sample(1).to_dict(orient="records")
resp = requests.post(server_url + path, json=item[0])
resp.content.decode("utf-8")
# Out:
# '138292.82830001073'

# %%
# test /predict_items

path = "/predict_items"
df = pd.read_csv(data_url)
df.sample(10).drop(columns="selling_price").to_csv(
    buffer := io.StringIO(), index=False
)
resp = requests.post(server_url + path, files={"csv": buffer.getvalue()})
pd.read_csv(io.BytesIO(resp.content))
# Out:
#                                      name  year  km_driven    fuel  \
# 0               Hyundai Verna 1.6 CRDi SX  2016      60000  Diesel
# 1  Toyota Innova 2.5 VX (Diesel) 7 Seater  2013      79328  Diesel
# 2                  Hyundai Santro Xing XG  2004     158000  Petrol
# 3              BMW X4 M Sport X xDrive20d  2019       7500  Diesel
# 4       Chevrolet Optra Magnum 2.0 LT BS3  2008     120000  Diesel
# 5             Hyundai Creta 1.4 CRDi Base  2017      45000  Diesel
# 6                        Maruti Swift LXI  2017      26000  Petrol
# 7                     Honda City 1.5 E MT  2008     120000  Petrol
# 8           Mahindra Scorpio 2.6 CRDe SLE  2011      70000  Diesel
# 9                     Maruti Alto K10 VXI  2017      30000  Petrol
#
#         seller_type transmission         owner     mileage   engine  \
# 0        Individual       Manual   First Owner   23.9 kmpl  1582 CC
# 1  Trustmark Dealer       Manual  Second Owner  12.99 kmpl  2494 CC
# 2        Individual       Manual   First Owner         NaN      NaN
# 3            Dealer    Automatic   First Owner  16.78 kmpl  1995 CC
# 4        Individual       Manual  Second Owner  16.52 kmpl  1991 CC
# 5        Individual       Manual   First Owner  21.38 kmpl  1396 CC
# 6        Individual       Manual  Second Owner  21.21 kmpl  1197 CC
# 7        Individual       Manual  Second Owner   17.0 kmpl  1497 CC
# 8        Individual       Manual  Second Owner   10.5 kmpl  2609 CC
# 9        Individual       Manual   First Owner  23.95 kmpl   998 CC
#
#    max_power                 torque  seats  selling_price
# 0  126.2 bhp  259.9Nm@ 1900-2750rpm    5.0   7.715539e+05
# 1  100.6 bhp    200Nm@ 1200-3600rpm    7.0   9.091831e+05
# 2        NaN                    NaN    NaN   1.017981e+05
# 3    190 bhp    400Nm@ 1750-2500rpm    5.0   3.811635e+06
# 4  123.7 bhp         305Nm@ 2000rpm    5.0   2.383421e+05
# 5   88.7 bhp  219.7Nm@ 1500-2750rpm    5.0   7.178373e+05
# 6  81.80 bhp         113Nm@ 4200rpm    5.0   4.792674e+05
# 7    118 bhp      146Nm at 4800 rpm    5.0   2.405873e+05
# 8    120 bhp    290Nm@ 1800-2800rpm    7.0   5.162904e+05
# 9  67.05 bhp          90Nm@ 3500rpm    5.0   3.763456e+05
